# %%
import import_ipynb
from WholePeriodBetas import return_df, pnl_df, backtest_data
# Out:
# importing Jupyter notebook from WholePeriodBetas.ipynb
# importing Jupyter notebook from dataprocess.ipynb
# [*********************100%***********************]  12 of 12 completed
# [*********************100%***********************]  12 of 12 completed
# [*********************100%***********************]  12 of 12 completed
# <string>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      pcost       dcost       gap    pres   dres
#  0: -8.9008e-06 -6.1282e+01  6e+01  1e-15  6e-16
#  1: -1.4900e-05 -6.4052e-01  6e-01  8e-16  1e-15
#  2: -5.3951e-04 -3.0435e-02  3e-02  2e-16  5e-17
#  3: -5.3556e-03 -1.0133e-02  5e-03  1e-15  6e-18
#  4: -7.7831e-03 -8.2519e-03  5e-04  8e-16  9e-19
#  5: -8.0078e-03 -8.0336e-03  3e-05  1e-15  7e-19
# ...

# %%
import pandas as pd
import numpy as np
from pandas.tseries.offsets import BusinessDay as Bday
import datetime as dt
import statsmodels.api as sm
import performanceanalytics.statistics as pas
import performanceanalytics.table.table as pat
import matplotlib.pyplot as plt
import seaborn as sns
import quantstats as qs

# %%
return_df.index = backtest_data[1:].index
ret = return_df['2007-11-21':'2009-03-31']
pnl_df.index = backtest_data.index
pnl = pnl_df['2007-11-21':'2009-03-31']

# %%
pnl.cumsum()
# Out:
#                   SPY  P&L Betas: -0.5  P&L Betas: 0  P&L Betas: 0.5  \
# Date
# 2007-11-21  -1.959306     5.684342e-14 -1.136868e-13   -1.136868e-13
# 2007-11-22  -1.148437    -4.217237e+00 -4.070931e+00   -3.849389e+00
# 2007-11-23  -0.337568    -8.434474e+00 -8.141862e+00   -7.698778e+00
# 2007-11-26  -2.442514    -9.670493e+00 -1.063575e+01   -1.162052e+01
# 2007-11-27  -1.370182    -3.371790e+01 -3.596894e+01   -3.812355e+01
# ...               ...              ...           ...             ...
# 2009-03-25 -39.839384     7.981228e+02  7.692235e+02    7.277367e+02
# 2009-03-26 -38.700040     8.727758e+02  8.629884e+02    8.329562e+02
# 2009-03-27 -39.729576     8.597089e+02  8.447613e+02    8.062411e+02
# 2009-03-30 -41.665023     9.481665e+02  9.189125e+02    8.626498e+02
# 2009-03-31 -41.164003     9.481665e+02  9.189125e+02    8.626498e+02
#
#             P&L Betas: 1.5
# Date
# 2007-11-21    1.136868e-13
# 2007-11-22   -3.136803e+00
# 2007-11-23   -6.273605e+00
# ...

# %%
#summarizing table
b = pd.DataFrame()
b['sharpe ratio']=qs.stats.sharpe(ret)
b['VaR']=qs.stats.value_at_risk(ret)
b.T
# Out:
#                    SPY  Beta: -0.5   Beta: 0  Beta: 0.5  Beta: 1.5
# sharpe ratio -0.833067    1.639045  1.602928   1.556343   1.311095
# VaR          -0.041553   -0.162296 -0.156335  -0.151987  -0.150448

# %%
pat.stats_table(ret, manager_col=0, other_cols=[1,2,3,4])
# Out:
#                          SPY    Beta: -0.5       Beta: 0     Beta: 0.5  \
# Observations      355.000000  3.550000e+02  3.550000e+02  3.550000e+02
# NAs                 0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# Minimum            -0.098448 -3.410709e-01 -3.228140e-01 -3.127652e-01
# Quartile 1         -0.012746 -3.515514e-02 -3.133989e-02 -3.278573e-02
# Median              0.000142  2.220446e-16  2.220446e-16  4.440892e-16
# Artithmetic Mean   -0.001285  1.086992e-02  1.022486e-02  9.633276e-03
# Geometric Mean     -0.001582  5.392760e-03  5.132536e-03  4.817584e-03
# Quartile 3          0.008609  7.171975e-02  7.143359e-02  6.228047e-02
# Maximum             0.145198  5.443333e-01  4.958930e-01  4.481183e-01
# SE Mean             0.001299  5.587550e-03  5.374396e-03  5.215004e-03
# LCL Mean (.95)     -0.001353  1.057501e-02  9.941202e-03  9.358026e-03
# UCL Mean (.95)     -0.001216  1.116483e-02  1.050853e-02  9.908526e-03
# ...

# %%
x = pnl.index[::5]
plt.plot(x,pnl['SPY'].cumsum()[::5],label = 'SPY')
plt.plot(x,pnl['P&L Betas: -0.5'].cumsum()[::5],label = 'beta: -0.5')
plt.plot(x,pnl['P&L Betas: 0'].cumsum()[::5],label = 'beta: 0')
plt.plot(x,pnl['P&L Betas: 0.5'][::5],label = 'beta: 0.5')
plt.plot(x,pnl['P&L Betas: 1.5'][::5],label = 'beta: 1.5')
plt.xlabel('year')
plt.ylabel('accumulated P&L')
plt.legend()

# %%
fig, axes = plt.subplots(2, 2,sharex= True, sharey = True)
sns.distplot(ret['Beta: -0.5'],ax= axes[0][0], hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = 'beta: -0.5')  
sns.distplot(ret['Beta: 0'],ax= axes[0][1], hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = 'beta: 0')  
sns.distplot(ret['Beta: 0.5'],ax= axes[1][0], hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = 'beta: 0.5')
sns.distplot(ret['Beta: 1.5'],ax= axes[1][1], hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = 'beta: 1.5')
# Out:
# C:\Users\Nhat Pham\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Nhat Pham\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...
